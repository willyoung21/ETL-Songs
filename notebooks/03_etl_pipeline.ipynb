# %%
import os
import pandas as pd
import re
from rapidfuzz import process, fuzz

# Función para normalizar texto
def normalize_text(text):
    if isinstance(text, str):
        text = text.lower()
        text = re.sub(r'[^a-zA-Z0-9\s]', '', text)  # Eliminar caracteres especiales
        text = re.sub(r'\s+', ' ', text).strip()  # Eliminar espacios adicionales
        text = re.sub(r'\b(feat|ft|featuring|remix|version)\b', '', text)  # Eliminar términos problemáticos
    return text

# Cargar los archivos CSV
spotify_csv_path = r'C:\Users\USUARIO\Documents\Workshop2\data\processed\spotify_cleaned.csv'
grammys_csv_path = r'C:\Users\USUARIO\Documents\Workshop2\data\processed\grammys_supercleaned.csv'  # Usamos el archivo con spotify_id

spotify_merge = pd.read_csv(spotify_csv_path)
grammy_merge = pd.read_csv(grammys_csv_path)

# Normalizar los nombres de los artistas, canciones y álbumes en ambos datasets
grammy_merge['artist_clean'] = grammy_merge['artist'].apply(normalize_text)
grammy_merge['nominee_clean'] = grammy_merge['nominee'].apply(normalize_text)
spotify_merge['artists_clean'] = spotify_merge['artists'].apply(normalize_text)
spotify_merge['track_name_clean'] = spotify_merge['track_name'].apply(normalize_text)
spotify_merge['album_name_clean'] = spotify_merge['album_name'].apply(normalize_text)

# Exploding para que cada artista en una lista tenga su propia fila
spotify_merge = spotify_merge.explode('artists_clean')

# Merge directo basado en 'spotify_id' y 'track_id'
merged_df = pd.merge(grammy_merge, spotify_merge, left_on='spotify_id', right_on='track_id', how='left')

# Encontrar las filas sin match en el merge basado en spotify_id
no_match_df = merged_df[merged_df['track_id'].isnull()]

# Si hay filas que no tienen match, hacemos la coincidencia difusa
song_threshold = 70  # Umbral
artist_threshold = 70
album_threshold = 60

matches = []
for i, row in no_match_df.iterrows():
    song_match = process.extractOne(row['nominee_clean'], spotify_merge['track_name_clean'], scorer=fuzz.ratio)
    
    # Buscar coincidencia con track_name
    if song_match and song_match[1] >= song_threshold:
        matched_rows = spotify_merge[spotify_merge['track_name_clean'] == song_match[0]]
        artist_matches = []
        
        for _, matched_row in matched_rows.iterrows():
            artist_match = process.extractOne(row['artist_clean'], [matched_row['artists_clean']], scorer=fuzz.ratio)
            if artist_match and artist_match[1] >= artist_threshold:
                artist_matches.append(matched_row)  # Solo añadir la fila completa
            
        if artist_matches:
            matches.extend(artist_matches)
        else:
            matches.append(row)
    else:
        # Buscar coincidencia con album_name si no hay coincidencia en track_name
        album_match = process.extractOne(row['nominee_clean'], spotify_merge['album_name_clean'], scorer=fuzz.ratio)
        if album_match and album_match[1] >= album_threshold:
            matched_rows = spotify_merge[spotify_merge['album_name_clean'] == album_match[0]]
            artist_matches = []
            
            for _, matched_row in matched_rows.iterrows():
                artist_match = process.extractOne(row['artist_clean'], [matched_row['artists_clean']], scorer=fuzz.ratio)
                if artist_match and artist_match[1] >= artist_threshold:
                    artist_matches.append(matched_row)  # Solo añadir la fila completa
            
            if artist_matches:
                matches.extend(artist_matches)
            else:
                matches.append(row)
        else:
            matches.append(row)
    
    # Mostrar el progreso cada 100 filas
    if (i + 1) % 100 == 0:
        print(f"Procesadas {i + 1} filas de {len(no_match_df)}")

# Crear un DataFrame con las coincidencias
fuzzy_matched_df = pd.DataFrame(matches)

# Concatenar los resultados del merge directo y las coincidencias difusas
final_merged_df = pd.concat([merged_df.reset_index(drop=True), fuzzy_matched_df.reset_index(drop=True)], ignore_index=True)

# Eliminar columnas auxiliares excepto 'spotify_id'
final_merged_df = final_merged_df.drop(columns=['artist_clean', 'nominee_clean', 'artists_clean', 'track_name_clean', 'album_name_clean'], errors='ignore')

# Asegurarse de que la columna 'spotify_id' se mantenga
if 'spotify_id' not in final_merged_df.columns:
    print("La columna 'spotify_id' no está presente en el DataFrame final.")
else:
    print("La columna 'spotify_id' está presente en el DataFrame final.")

# Eliminar duplicados
final_merged_df = final_merged_df.drop_duplicates(subset=['nominee', 'artist', 'category'])

# Comprobar la cantidad de filas después del merge
merged_count = final_merged_df.shape[0]
print(f"Cantidad de filas después del merge: {merged_count}")

# Opcional: Verificar las primeras filas del DataFrame limpio
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
final_merged_df.head(20)

# Opcional: Guardar el DataFrame resultante en un archivo CSV
output_path = r'C:\Users\USUARIO\Documents\Workshop2\data\Merge1.csv'
final_merged_df.to_csv(output_path, index=False)
print(f"Merge completado y archivo guardado como '{output_path}'.")
# Out:
# Procesadas 100 filas de 4266
# Procesadas 200 filas de 4266
# Procesadas 300 filas de 4266
# Procesadas 400 filas de 4266
# Procesadas 500 filas de 4266
# Procesadas 600 filas de 4266
# Procesadas 700 filas de 4266
# Procesadas 800 filas de 4266
# Procesadas 900 filas de 4266
# Procesadas 1000 filas de 4266
# Procesadas 1200 filas de 4266
# Procesadas 1500 filas de 4266
# Procesadas 1600 filas de 4266
# Procesadas 1800 filas de 4266
# Procesadas 1900 filas de 4266
# Procesadas 2000 filas de 4266
# Procesadas 2100 filas de 4266
# Procesadas 2200 filas de 4266
# Procesadas 2300 filas de 4266
# Procesadas 2400 filas de 4266
# Procesadas 2500 filas de 4266
# Procesadas 2600 filas de 4266
# Procesadas 2800 filas de 4266
# Procesadas 2900 filas de 4266
# Procesadas 3000 filas de 4266
# Procesadas 3100 filas de 4266
# Procesadas 3200 filas de 4266
# Procesadas 3400 filas de 4266
# Procesadas 3500 filas de 4266
# Procesadas 3600 filas de 4266
# Procesadas 3700 filas de 4266
# Procesadas 3800 filas de 4266
# Procesadas 3900 filas de 4266
# Procesadas 4000 filas de 4266
# Procesadas 4200 filas de 4266
# Procesadas 4400 filas de 4266
# Procesadas 4500 filas de 4266
# Procesadas 5000 filas de 4266
# Procesadas 5100 filas de 4266
# La columna 'spotify_id' está presente en el DataFrame final.
# Cantidad de filas después del merge: 4757
# Merge completado y archivo guardado como 'C:\Users\USUARIO\Documents\Workshop2\data\Merge1.csv'.

# %%
# Opcional: Verificar las primeras filas del DataFrame limpio
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
final_merged_df.head(20)
# Out:
#         id    year                              title  \
# 0      1.0  2019.0  62nd Annual GRAMMY Awards  (2019)
# 1      2.0  2019.0  62nd Annual GRAMMY Awards  (2019)
# 2      3.0  2019.0  62nd Annual GRAMMY Awards  (2019)
# 3      4.0  2019.0  62nd Annual GRAMMY Awards  (2019)
# 4      5.0  2019.0  62nd Annual GRAMMY Awards  (2019)
# 5      6.0  2019.0  62nd Annual GRAMMY Awards  (2019)
# 6      7.0  2019.0  62nd Annual GRAMMY Awards  (2019)
# 7      8.0  2019.0  62nd Annual GRAMMY Awards  (2019)
# 8      9.0  2019.0  62nd Annual GRAMMY Awards  (2019)
# 9     10.0  2019.0  62nd Annual GRAMMY Awards  (2019)
# 10    11.0  2019.0  62nd Annual GRAMMY Awards  (2019)
# 11    12.0  2019.0  62nd Annual GRAMMY Awards  (2019)
# 12    13.0  2019.0  62nd Annual GRAMMY Awards  (2019)
# 13    14.0  2019.0  62nd Annual GRAMMY Awards  (2019)
# 14    15.0  2019.0  62nd Annual GRAMMY Awards  (2019)
# 15    16.0  2019.0  62nd Annual GRAMMY Awards  (2019)
# 16    17.0  2019.0  62nd Annual GRAMMY Awards  (2019)
# 17    18.0  2019.0  62nd Annual GRAMMY Awards  (2019)
# 18  3354.0  1987.0  30th Annual GRAMMY Awards  (1987)
# 19    19.0  2019.0  62nd Annual GRAMMY Awards  (2019)
#
#                                  category  \
# 0                      Record Of The Year
# 1                      Record Of The Year
# 2                      Record Of The Year
# 3                      Record Of The Year
# 4                      Record Of The Year
# 5                      Record Of The Year
# 6                      Record Of The Year
# 7                      Record Of The Year
# 8                       Album Of The Year
# 9                       Album Of The Year
# 10                      Album Of The Year
# 11                      Album Of The Year
# 12                      Album Of The Year
# 13                      Album Of The Year
# 14                      Album Of The Year
# 15                      Album Of The Year
# 16                       Song Of The Year
# 17                       Song Of The Year
# 18  Producer Of The Year, (Non Classical)
# 19                       Song Of The Year
#
#                                      nominee  \
# 0                                    Bad Guy
# 1                                    Hey, Ma
# 2                                    7 rings
# 3                                 Hard Place
# 4                                       Talk
# 5                              Old Town Road
# 6                                Truth Hurts
# 7                                  Sunflower
# 8   When We All Fall Asleep, Where Do We Go?
# 9                                        I,I
# 10                  Norman F***ing Rockwell!
# 11                             thank u, next
# 12                        I Used To Know Her
# 13                                         7
# 14                   Cuz I Love You (Deluxe)
# 15                       Father Of The Bride
# 16                                   Bad Guy
# 17               Always Remember Us This Way
# 18                     Narada Michael Walden
# 19                      Bring My Flowers Now
#
#                                  artist  \
# 0                         Billie Eilish
# 1                              Bon Iver
# 2                         Ariana Grande
# 3                                H.E.R.
# 4                                Khalid
# 5   Lil Nas X Featuring Billy Ray Cyrus
# 6                                 Lizzo
# 7                Post Malone & Swae Lee
# 8                         Billie Eilish
# 9                              Bon Iver
# 10                         Lana Del Rey
# 11                        Ariana Grande
# 12                               H.E.R.
# 13                            Lil Nas X
# 14                                Lizzo
# 15                      Vampire Weekend
# 16                        Billie Eilish
# 17                            Lady Gaga
# 18                Narada Michael Walden
# 19                         Tanya Tucker
#
#                                               workers winner  \
# 0   Finneas O'Connell, producer; Rob Kinelski & Fi...   True
# 1   BJ Burton, Brad Cook, Chris Messina & Justin V...   True
# 2   Charles Anderson, Tommy Brown, Michael Foster ...   True
# 3   Rodney “Darkchild” Jerkins, producer; Joseph H...   True
# 4   Disclosure & Denis Kosiak, producers; Ingmar C...   True
# 5   Andrew "VoxGod" Bolooki, Jocelyn “Jozzy” Donal...   True
# 6   Ricky Reed & Tele, producers; Chris Galland, M...   True
# 7   Louis Bell & Carter Lang, producers; Louis Bel...   True
# 8   Finneas O'Connell, producer; Rob Kinelski & Fi...   True
# 9   Brad Cook, Chris Messina & Justin Vernon, prod...   True
# 10  Jack Antonoff & Lana Del Rey, producers; Jack ...   True
# 11  Tommy Brown, Ilya, Max Martin & Victoria Monet...   True
# 12  David "Swagg R'Celious" Harris, H.E.R., Walter...   True
# 13  Joe Grasso, engineer/mixer; Montero Lamar Hill...   True
# 14  Ricky Reed, producer; Manny Marroquin & Ethan ...   True
# 15  Ezra Koenig & Ariel Rechtshaid, producers; Joh...   True
# 16  Billie Eilish O'Connell & Finneas O'Connell, s...   True
# 17  Natalie Hemby, Lady Gaga, Hillary Lindsey & Lo...   True
# 18                                     unknown worker   True
# 19  Brandi Carlile, Phil Hanseroth, Tim Hanseroth ...   True
#
#                 spotify_id  Unnamed: 0                track_id  \
# 0   2Fxmhks0bxGSBdJ92vM42m     31018.0  2Fxmhks0bxGSBdJ92vM42m
# 1   0RstfX9nRY1Lfuy1808MoT         NaN  0RstfX9nRY1Lfuy1808MoT
# 2   6ocbgoVGwYJhOv1GgI9NsF     20009.0  6ocbgoVGwYJhOv1GgI9NsF
# 3   4IablJ6SqVNGY4vrseyKxu         NaN  4IablJ6SqVNGY4vrseyKxu
# 4   6g6A7qNhTfUgOSH7ROOxTD         NaN  6g6A7qNhTfUgOSH7ROOxTD
# 5   0F7FA14euOIX8KcbEturGH     51251.0  0F7FA14euOIX8KcbEturGH
# 6   3HWzoMvoF3TQfYg4UPszDq         NaN  3HWzoMvoF3TQfYg4UPszDq
# 7   3KkXRkHbMCARz0aVfEt68P         NaN  3KkXRkHbMCARz0aVfEt68P
# 8   43zdsphuZLzwA9k4DJhU0I         NaN  43zdsphuZLzwA9k4DJhU0I
# 9   3ihJ79kKH1P3YrOznRSDIA         NaN  3ihJ79kKH1P3YrOznRSDIA
# 10  3RIgHHpnFKj5Rni1shokDj         NaN  3RIgHHpnFKj5Rni1shokDj
# 11  3e9HZxeyfWwjeyPAMmWSSQ     20303.0  3e9HZxeyfWwjeyPAMmWSSQ
# 12  6oEVnWKgPqIEPc53OYDNqG         NaN  6oEVnWKgPqIEPc53OYDNqG
# 13  5kqIPrATaCc2LqxVWzQGbk         NaN  5kqIPrATaCc2LqxVWzQGbk
# 14  3HWzoMvoF3TQfYg4UPszDq         NaN  3HWzoMvoF3TQfYg4UPszDq
# 15  39exKIvycQDgs4T6uXdyu0         NaN  39exKIvycQDgs4T6uXdyu0
# 16  2Fxmhks0bxGSBdJ92vM42m     31018.0  2Fxmhks0bxGSBdJ92vM42m
# 17  2rbDhOo9Fh61Bbu23T2qCk         NaN  2rbDhOo9Fh61Bbu23T2qCk
# 18  0PjkD419FrFnRuS5Mgs6pm         NaN  0PjkD419FrFnRuS5Mgs6pm
# 19  7nx130yomv3fvvFD0fcGOG         NaN  7nx130yomv3fvvFD0fcGOG
#
#                    artists                                         album_name  \
# 0            Billie Eilish           WHEN WE ALL FALL ASLEEP, WHERE DO WE GO?
# 1                 Bon Iver                                                i,i
# 2            Ariana Grande                                      thank u, next
# 3                   H.E.R.                                         Hard Place
# 4   Jason Derulo, 2 Chainz                                         Talk Dirty
# 5                Lil Nas X                                               7 EP
# 6                    Lizzo                      Cuz I Love You (Super Deluxe)
# 7    Post Malone, Swae Lee  Spider-Man: Into the Spider-Verse (Soundtrack ...
# 8            Billie Eilish           WHEN WE ALL FALL ASLEEP, WHERE DO WE GO?
# 9           Lovejoy Street                                         Exit Signs
# 10            Lana Del Rey                           Norman Fucking Rockwell!
# 11           Ariana Grande                                      thank u, next
# 12   H.E.R., Bryson Tiller                                 I Used To Know Her
# 13            Lukas Graham                                       Lukas Graham
# 14                   Lizzo                      Cuz I Love You (Super Deluxe)
# 15         Vampire Weekend                                Father of the Bride
# 16           Billie Eilish           WHEN WE ALL FALL ASLEEP, WHERE DO WE GO?
# 17               Lady Gaga       A Star Is Born Soundtrack (Without Dialogue)
# 18   Narada Michael Walden                                  The Dance Of Life
# 19            Tanya Tucker                                   While I'm Livin'
#
#                                        track_name  popularity  duration_ms  \
# 0                                         bad guy        84.0     194087.0
# 1                                         Hey, Ma        58.0     216706.0
# 2                                         7 rings        84.0     178626.0
# 3                                      Hard Place        54.0     271733.0
# 4                     Talk Dirty (feat. 2 Chainz)        67.0     177685.0
# 5                                   Old Town Road        77.0     113000.0
# 6                                     Truth Hurts        70.0     173325.0
# 7   Sunflower - Spider-Man: Into the Spider-Verse        80.0     158040.0
# 8                           when the party's over        83.0     196077.0
# 9                                             I,I         0.0     185251.0
# 10                        Norman fucking Rockwell        73.0     248934.0
# 11                                  thank u, next        82.0     207320.0
# 12            Could've Been (feat. Bryson Tiller)        75.0     252746.0
# 13                                        7 Years        81.0     237300.0
# 14                                    Truth Hurts        70.0     173325.0
# 15                                   Harmony Hall        59.0     308733.0
# 16                                        bad guy        84.0     194087.0
# 17                    Always Remember Us This Way        83.0     210200.0
# 18                             I Shoulda Loved Ya        36.0     397133.0
# 19                           Bring My Flowers Now        34.0     260360.0
#
#     danceability  energy    tempo track_genre
# 0          0.701   0.425  135.128     electro
# 1          0.325   0.286  144.296        None
# 2          0.778   0.317  140.048       dance
# 3          0.614   0.719  160.075        None
# 4          0.760   0.652  100.315        None
# 5          0.907   0.530  135.998     hip-hop
# 6          0.715   0.624  158.087        None
# 7          0.760   0.478   89.908        None
# 8          0.367   0.111   82.642        None
# 9          0.568   0.709  106.040        None
# 10         0.215   0.203   78.287        None
# 11         0.717   0.653  106.966       dance
# 12         0.450   0.352  102.679        None
# 13         0.765   0.473  119.992        None
# 14         0.715   0.624  158.087        None
# 15         0.653   0.760   98.008        None
# 16         0.701   0.425  135.128     electro
# 17         0.549   0.502  129.842        None
# 18         0.759   0.598  113.807        None
# 19         0.557   0.198  133.823        None

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
from dotenv import load_dotenv

# Cargar variables de entorno
load_dotenv()

# Configurar la autenticación
client_id = os.getenv('SPOTIFY_CLIENT_ID')
client_secret = os.getenv('SPOTIFY_CLIENT_SECRET')

client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# Verifica que la autenticación haya sido exitosa
print("Conectado a Spotify API")
# Out:
# Conectado a Spotify API

# %%
import pandas as pd
import requests

# Ruta del archivo CSV
csv_path = r'C:\Users\USUARIO\Documents\Workshop2\data\Merge1.csv'

# Cargar el archivo CSV
final_merged_df = pd.read_csv(csv_path)

# Verificar si las columnas necesarias existen
required_columns = ['track_id', 'spotify_id']
for col in required_columns:
    if col not in final_merged_df.columns:
        raise ValueError(f"La columna '{col}' no se encuentra en el DataFrame.")

# Definir una función para consultar la API de Spotify (información del track)
def get_spotify_info(spotify_id, access_token):
    url = f"https://api.spotify.com/v1/tracks/{spotify_id}"
    headers = {
        "Authorization": f"Bearer {access_token}"
    }
    try:
        response = requests.get(url, headers=headers)
        response.raise_for_status()  # Lanza un error si la respuesta no es 200
        return response.json()  # Devuelve los datos de la canción
    except requests.exceptions.RequestException as e:
        print(f"Error al obtener información del track {spotify_id}: {e}")
        return None  # Manejo de error

# Definir una función para consultar la API de Spotify (características de audio)
def get_audio_features(spotify_id, access_token):
    url = f"https://api.spotify.com/v1/audio-features/{spotify_id}"
    headers = {
        "Authorization": f"Bearer {access_token}"
    }
    try:
        response = requests.get(url, headers=headers)
        response.raise_for_status()  # Lanza un error si la respuesta no es 200
        return response.json()  # Devuelve las características de audio
    except requests.exceptions.RequestException as e:
        print(f"Error al obtener características de audio para {spotify_id}: {e}")
        return None  # Manejo de error

# Token de acceso (debes actualizar esto con tu token válido)
ACCESS_TOKEN = 'BQAdZQgp9lRNQSjs-AzuyWQy85jEgZSIQPMmSahJCiIwpN-8owQ8mYx6Lpd0DeQPDgB_LteoMCUWngUimI1WeR94ezPj5pE2llwe_0eIAkXnJVzuE4Q'

# Iterar sobre el DataFrame para llenar los NaN
for index, row in final_merged_df[final_merged_df['track_id'].isnull()].iterrows():
    spotify_id = row['spotify_id']  # Asegúrate de que esta columna existe
    
    if pd.notna(spotify_id):  # Verificar si el spotify_id no es NaN
        try:
            # Obtener información del track de Spotify
            track_info = get_spotify_info(spotify_id, ACCESS_TOKEN)
            
            if track_info:
                # Rellenar columnas relevantes
                final_merged_df.loc[index, 'track_id'] = track_info.get('id')
                final_merged_df.loc[index, 'artists'] = ', '.join([artist['name'] for artist in track_info.get('artists', [])])
                final_merged_df.loc[index, 'album_name'] = track_info.get('album', {}).get('name')
                final_merged_df.loc[index, 'track_name'] = track_info.get('name')
                final_merged_df.loc[index, 'popularity'] = track_info.get('popularity')
                final_merged_df.loc[index, 'duration_ms'] = track_info.get('duration_ms')
            
                # Obtener características de audio
                audio_features = get_audio_features(spotify_id, ACCESS_TOKEN)
                
                if audio_features:
                    final_merged_df.loc[index, 'danceability'] = audio_features.get('danceability')
                    final_merged_df.loc[index, 'energy'] = audio_features.get('energy')
                    final_merged_df.loc[index, 'tempo'] = audio_features.get('tempo')
                    final_merged_df.loc[index, 'track_genre'] = track_info.get('genre', None)  # Si el género está disponible
                
            # Mostrar progreso cada 100 filas
            if index % 100 == 0:
                print(f"Información rellenada en fila {index}")
        
        except Exception as e:
            print(f"Error al procesar fila {index}: {e}")

# Comprobar cuántas filas siguen teniendo NaN después del proceso
remaining_nan_counts = final_merged_df.isnull().sum()
print("Conteo de NaN después del proceso:")
print(remaining_nan_counts)

# Opcional: Verificar las primeras filas del DataFrame limpio
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
print(final_merged_df.head(20))  # Asegúrate de imprimir el DataFrame

# Guardar el resultado actualizado en un nuevo archivo CSV (opcional)
#output_path = r'C:\Users\USUARIO\Documents\Workshop2\notebooks\Merged_Updated.csv'
#final_merged_df.to_csv(output_path, index=False)
#print(f"Archivo actualizado guardado en: {output_path}")
# Out:
# Información rellenada en fila 100
# Información rellenada en fila 200
# Información rellenada en fila 300
# Error al obtener información del track 65PQMTZdPm2YjRLmcC5OJA: 404 Client Error: Not Found for url: https://api.spotify.com/v1/tracks/65PQMTZdPm2YjRLmcC5OJA
# Información rellenada en fila 400
# Información rellenada en fila 500
# Información rellenada en fila 600
# Información rellenada en fila 800
# Información rellenada en fila 900
# Información rellenada en fila 1000
# Información rellenada en fila 1100
# Información rellenada en fila 1200
# Información rellenada en fila 1300
# Información rellenada en fila 1500
# Información rellenada en fila 1600
# Información rellenada en fila 1700
# Información rellenada en fila 1900
# Información rellenada en fila 2000
# Información rellenada en fila 2100
# Información rellenada en fila 2200
# Error al obtener características de audio para 5IgX3rn7NTdtuuMwe0lytM: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/5IgX3rn7NTdtuuMwe0lytM
# Información rellenada en fila 2300
# Error al obtener características de audio para 4J4Yx1ev1og69BKMtKVERL: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/4J4Yx1ev1og69BKMtKVERL
# Error al obtener características de audio para 4IVyX0UJzGyUk0MLiz1jVJ: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/4IVyX0UJzGyUk0MLiz1jVJ
# Error al obtener características de audio para 1ukyoZde6M7HdoH0xGE3nB: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/1ukyoZde6M7HdoH0xGE3nB
# Error al obtener características de audio para 3WLDpY3HK7d7ezz28257Y2: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/3WLDpY3HK7d7ezz28257Y2
# Error al obtener características de audio para 7n14OIikBlKLOqLdECn1SP: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/7n14OIikBlKLOqLdECn1SP
# Error al obtener características de audio para 1pjXQaJXYUUz3NMd8Z7lt8: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/1pjXQaJXYUUz3NMd8Z7lt8
# Error al obtener características de audio para 77UjLW8j5UAGAGVGhR5oUK: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/77UjLW8j5UAGAGVGhR5oUK
# Error al obtener características de audio para 0XPsOSYzDJZJArevQNm2AR: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/0XPsOSYzDJZJArevQNm2AR
# Error al obtener características de audio para 4ZJNmmHhMVXNcf2Ic0ZD87: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/4ZJNmmHhMVXNcf2Ic0ZD87
# Error al obtener características de audio para 3D9RcDmY7M4xKo9ynpPANp: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/3D9RcDmY7M4xKo9ynpPANp
# Error al obtener características de audio para 4cNbCWPJjLHP5ijow5LbVg: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/4cNbCWPJjLHP5ijow5LbVg
# Error al obtener características de audio para 4a0fMCaGIW7wVQyQcqC963: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/4a0fMCaGIW7wVQyQcqC963
# Error al obtener características de audio para 1UoCDn52urzsC0Uoo4odt4: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/1UoCDn52urzsC0Uoo4odt4
# Error al obtener características de audio para 52npaqR46zxS9F73TP2ScN: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/52npaqR46zxS9F73TP2ScN
# Error al obtener características de audio para 3QgMBFVVzI4Za8Q3R8yWIE: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/3QgMBFVVzI4Za8Q3R8yWIE
# Error al obtener características de audio para 621LLhcTYkEbt1fwJuSdWi: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/621LLhcTYkEbt1fwJuSdWi
# Error al obtener características de audio para 7gNI9f8NTCU6hLV0pLkTT7: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/7gNI9f8NTCU6hLV0pLkTT7
# Error al obtener características de audio para 4oRZkVkEC5c3IXsLGgahEY: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/4oRZkVkEC5c3IXsLGgahEY
# Error al obtener características de audio para 4xz3AATOzLtI2d1GSZ5Bb8: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/4xz3AATOzLtI2d1GSZ5Bb8
# Error al obtener características de audio para 63wEUQ8SN2S8nx2r21zTnl: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/63wEUQ8SN2S8nx2r21zTnl
# Error al obtener características de audio para 1hkRA6wQjIQ4S37zPWRNWL: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/1hkRA6wQjIQ4S37zPWRNWL
# Error al obtener características de audio para 10FWYdwqDWljDsxSkCDdmD: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/10FWYdwqDWljDsxSkCDdmD
# Error al obtener características de audio para 3GlYv2EDC7EBoslv2dOE0G: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/3GlYv2EDC7EBoslv2dOE0G
# Error al obtener características de audio para 1VxXtBOvbfSHO35y8YArg0: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/1VxXtBOvbfSHO35y8YArg0
# Error al obtener características de audio para 4BJqCMejKcq2ZgbZdjHSqd: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/4BJqCMejKcq2ZgbZdjHSqd
# Error al obtener características de audio para 1cHtD5Cg04ccQpocU59v4Q: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/1cHtD5Cg04ccQpocU59v4Q
# Error al obtener características de audio para 1lqerVsQVt5kl1MZknTf2K: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/1lqerVsQVt5kl1MZknTf2K
# Error al obtener características de audio para 0aqitRAbD05trPI53gzBYJ: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/0aqitRAbD05trPI53gzBYJ
# Error al obtener características de audio para 2Q6ocuzb8ZOn8guLKKxk6N: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/2Q6ocuzb8ZOn8guLKKxk6N
# Error al obtener características de audio para 3mkc6mE4s4UUOOfqY6FRVr: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/3mkc6mE4s4UUOOfqY6FRVr
# Error al obtener características de audio para 1rmtygBvOF8Wb1OwVMAyaE: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/1rmtygBvOF8Wb1OwVMAyaE
# Error al obtener características de audio para 407YIDqsL4S3ZJ2BOFg4P0: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/407YIDqsL4S3ZJ2BOFg4P0
# Error al obtener características de audio para 41HThCPpSezJaBne2uSNQV: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/41HThCPpSezJaBne2uSNQV
# Error al obtener características de audio para 7oJUv1pCZqI0Jsq5s31KB9: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/7oJUv1pCZqI0Jsq5s31KB9
# Error al obtener características de audio para 2wxy1aZya6S7mYZAn2m3I3: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/2wxy1aZya6S7mYZAn2m3I3
# Error al obtener características de audio para 0QLMAhZQACGtzi11XZVa6A: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/0QLMAhZQACGtzi11XZVa6A
# Error al obtener características de audio para 1r0E3QgXtjU5ezGmSBWY0y: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/1r0E3QgXtjU5ezGmSBWY0y
# Error al obtener características de audio para 2nRl16RtO2SUbkdT860Fed: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/2nRl16RtO2SUbkdT860Fed
# Error al obtener características de audio para 7KhoaZ8qfgJ1rlcI9UEt9u: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/7KhoaZ8qfgJ1rlcI9UEt9u
# Error al obtener características de audio para 51gEDxs1kClPad80zECJsq: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/51gEDxs1kClPad80zECJsq
# Error al obtener características de audio para 4IVyX0UJzGyUk0MLiz1jVJ: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/4IVyX0UJzGyUk0MLiz1jVJ
# Error al obtener características de audio para 40MdsY7YQn0Vo5uykWikAy: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/40MdsY7YQn0Vo5uykWikAy
# Error al obtener características de audio para 0mTUTkFQ2MxmUHFL8EdfeR: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/0mTUTkFQ2MxmUHFL8EdfeR
# Error al obtener características de audio para 65K52fqYeWRgVMLFTVBDmh: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/65K52fqYeWRgVMLFTVBDmh
# Error al obtener características de audio para 0mTUTkFQ2MxmUHFL8EdfeR: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/0mTUTkFQ2MxmUHFL8EdfeR
# Error al obtener características de audio para 0mTUTkFQ2MxmUHFL8EdfeR: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/0mTUTkFQ2MxmUHFL8EdfeR
# Error al obtener características de audio para 1ZlbBiEVWc19EWVorrHwU0: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/1ZlbBiEVWc19EWVorrHwU0
# Error al obtener características de audio para 5MyPGD5xJTqe1ojMkuAvzC: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/5MyPGD5xJTqe1ojMkuAvzC
# Error al obtener características de audio para 0kG9LyKQIvd6Y8pC2au2h6: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/0kG9LyKQIvd6Y8pC2au2h6
# Error al obtener características de audio para 069SOoG7uHJ2JY1QHpQFJR: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/069SOoG7uHJ2JY1QHpQFJR
# Error al obtener características de audio para 298QgpoW98lsDj7IK5ShHc: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/298QgpoW98lsDj7IK5ShHc
# Error al obtener características de audio para 68qVufgchRf9CFKhu8Iflt: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/68qVufgchRf9CFKhu8Iflt
# Error al obtener características de audio para 194Dao2JMcZt9bsorBQKma: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/194Dao2JMcZt9bsorBQKma
# Error al obtener características de audio para 7vX7bA0232CXVRb8w67seQ: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/7vX7bA0232CXVRb8w67seQ
# Error al obtener características de audio para 0E0MCO1Hqq87nWeJlPRG0P: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/0E0MCO1Hqq87nWeJlPRG0P
# Error al obtener características de audio para 2OL0lQNFVVHKRj6FgKzdT1: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/2OL0lQNFVVHKRj6FgKzdT1
# Error al obtener características de audio para 33LC84JgLvK2KuW43MfaNq: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/33LC84JgLvK2KuW43MfaNq
# Error al obtener características de audio para 0uEp9E98JB5awlA084uaIg: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/0uEp9E98JB5awlA084uaIg
# Error al obtener características de audio para 33LC84JgLvK2KuW43MfaNq: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/33LC84JgLvK2KuW43MfaNq
# Error al obtener características de audio para 2VjXGuPVVxyhMgER3Uz2Fe: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/2VjXGuPVVxyhMgER3Uz2Fe
# Error al obtener características de audio para 33LC84JgLvK2KuW43MfaNq: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/33LC84JgLvK2KuW43MfaNq
# Error al obtener características de audio para 2GGskYwS4j8LDMSDUJ8vrl: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/2GGskYwS4j8LDMSDUJ8vrl
# Error al obtener características de audio para 7FuRjlwyTY9uTAUgGpZtJU: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/7FuRjlwyTY9uTAUgGpZtJU
# Error al obtener características de audio para 0Dp7bRXdRXFqAMJRmW6MfV: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/0Dp7bRXdRXFqAMJRmW6MfV
# Error al obtener características de audio para 0yK8sWD6cfrc7pGfaPIcZH: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/0yK8sWD6cfrc7pGfaPIcZH
# Error al obtener características de audio para 4Fpsa3pYc3gozrxHRRPvR6: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/4Fpsa3pYc3gozrxHRRPvR6
# Error al obtener características de audio para 4Fpsa3pYc3gozrxHRRPvR6: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/4Fpsa3pYc3gozrxHRRPvR6
# Error al obtener características de audio para 6VXgxD1GfeG7RGlP98qd14: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/6VXgxD1GfeG7RGlP98qd14
# Error al obtener características de audio para 7c1iI6dwdCpHGYT8DGEfab: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/7c1iI6dwdCpHGYT8DGEfab
# Error al obtener características de audio para 1OxcIUqVmVYxT6427tbhDW: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/1OxcIUqVmVYxT6427tbhDW
# Error al obtener características de audio para 1k2pQc5i348DCHwbn5KTdc: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/1k2pQc5i348DCHwbn5KTdc
# Error al obtener características de audio para 6QA4FqB7HkiYoeJ5RvhfWq: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/6QA4FqB7HkiYoeJ5RvhfWq
# Error al obtener características de audio para 4s00FjlhSavgbNiRtpXhRj: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/4s00FjlhSavgbNiRtpXhRj
# Error al obtener características de audio para 4RSVaT769OstCHABytr1m7: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/4RSVaT769OstCHABytr1m7
# Error al obtener características de audio para 7c1iI6dwdCpHGYT8DGEfab: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/7c1iI6dwdCpHGYT8DGEfab
# Error al obtener características de audio para 1eKPBcUKstvi0UKNvpSbl1: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/1eKPBcUKstvi0UKNvpSbl1
# Error al obtener características de audio para 5fpizYGbi5IQoEraj6FP0R: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/5fpizYGbi5IQoEraj6FP0R
# Error al obtener características de audio para 0uEp9E98JB5awlA084uaIg: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/0uEp9E98JB5awlA084uaIg
# Error al obtener características de audio para 3cw8eL6EI64aCw9Mw6Ipgd: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/3cw8eL6EI64aCw9Mw6Ipgd
# Error al obtener características de audio para 6sHsXIJoEN5JpdkGMQDJxt: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/6sHsXIJoEN5JpdkGMQDJxt
# Error al obtener características de audio para 0uEp9E98JB5awlA084uaIg: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/0uEp9E98JB5awlA084uaIg
# Error al obtener características de audio para 0uEp9E98JB5awlA084uaIg: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/0uEp9E98JB5awlA084uaIg
# Error al obtener características de audio para 69A3RyQQwoHMkNgqxBtSMG: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/69A3RyQQwoHMkNgqxBtSMG
# Error al obtener características de audio para 0weAUscowxeqDtpCgtbpgp: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/0weAUscowxeqDtpCgtbpgp
# Error al obtener características de audio para 0rVd7bTGtrQUW34xSLzozd: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/0rVd7bTGtrQUW34xSLzozd
# Error al obtener características de audio para 5Tl0HJvynZtKdSUMKbFVVX: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/5Tl0HJvynZtKdSUMKbFVVX
# Error al obtener características de audio para 6ClUwlYW2JeMQryMhBK8DU: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/6ClUwlYW2JeMQryMhBK8DU
# Error al obtener características de audio para 3XNThMhQwdrRvPax42wzKQ: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/3XNThMhQwdrRvPax42wzKQ
# Error al obtener características de audio para 5KMWwtJv3Ll2ROZfMerQs0: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/5KMWwtJv3Ll2ROZfMerQs0
# Error al obtener características de audio para 7J8RIyWm1GLl54zmNk707M: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/7J8RIyWm1GLl54zmNk707M
# Error al obtener características de audio para 6cjwec9ii5uLK7CDfPBYt1: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/6cjwec9ii5uLK7CDfPBYt1
# Error al obtener características de audio para 6PDYYInELSMd6F71CYkMTq: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/6PDYYInELSMd6F71CYkMTq
# Error al obtener características de audio para 0p4zxScTH4QBPnDdIeInfB: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/0p4zxScTH4QBPnDdIeInfB
# Error al obtener características de audio para 4ufGuRB8PEv98bn2OH4bmR: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/4ufGuRB8PEv98bn2OH4bmR
# Error al obtener características de audio para 0nBGIx5yWqxvtf1EEnEGgm: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/0nBGIx5yWqxvtf1EEnEGgm
# Error al obtener características de audio para 18zor3AtbcQGbybMNYHwXg: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/18zor3AtbcQGbybMNYHwXg
# Información rellenada en fila 2400
# Error al obtener características de audio para 1rzV9wr9myXgDWvTcfIiq4: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/1rzV9wr9myXgDWvTcfIiq4
# Error al obtener características de audio para 5bjDadKhSzdKK8sy5FGgAI: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/5bjDadKhSzdKK8sy5FGgAI
# Error al obtener características de audio para 5CMVEnnJC2tATWKbvx6Wc8: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/5CMVEnnJC2tATWKbvx6Wc8
# Error al obtener características de audio para 2CoTCYjp9RKq4KPeu9HOmh: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/2CoTCYjp9RKq4KPeu9HOmh
# Error al obtener características de audio para 3NBWUPeHvIfqoVPxHrnPl1: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/3NBWUPeHvIfqoVPxHrnPl1
# Error al obtener características de audio para 3hfPPuxJtMoqPfhINjtzD1: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/3hfPPuxJtMoqPfhINjtzD1
# Error al obtener características de audio para 2PpQKFpmGfOGWuewvZ5RPN: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/2PpQKFpmGfOGWuewvZ5RPN
# Error al obtener características de audio para 4xm2HjtDAdCobewPoaImT7: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/4xm2HjtDAdCobewPoaImT7
# Error al obtener características de audio para 60fniRXixufxR4HCYjOyp6: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/60fniRXixufxR4HCYjOyp6
# Error al obtener características de audio para 78DVpEWwmJFC25KGz8fJuE: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/78DVpEWwmJFC25KGz8fJuE
# Error al obtener características de audio para 22GxtWFeORJZaptz26pxet: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/22GxtWFeORJZaptz26pxet
# Error al obtener características de audio para 1mycUAMDC2PS8yTgmxlL79: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/1mycUAMDC2PS8yTgmxlL79
# Error al obtener características de audio para 1bNzEYfvxscJO2FGB4iCRj: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/1bNzEYfvxscJO2FGB4iCRj
# Error al obtener características de audio para 0MJh8pgvE8KtM077ynnVjC: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/0MJh8pgvE8KtM077ynnVjC
# Error al obtener características de audio para 4Ilen0VxPEsVRLpnePji8P: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/4Ilen0VxPEsVRLpnePji8P
# Error al obtener características de audio para 72c8xtBefXffG64Dymjti5: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/72c8xtBefXffG64Dymjti5
# Error al obtener características de audio para 5rUqENE7bmNffBbZDhVBty: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/5rUqENE7bmNffBbZDhVBty
# Error al obtener características de audio para 4AF3Jh47cnMkW13Tr91NSe: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/4AF3Jh47cnMkW13Tr91NSe
# Error al obtener características de audio para 2GORop0i2cyx8C0A3JzL44: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/2GORop0i2cyx8C0A3JzL44
# Error al obtener características de audio para 5ozIJbMZUZf695eQq5A8F9: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/5ozIJbMZUZf695eQq5A8F9
# Error al obtener características de audio para 4LnsKghmIO0SXeUL3I20q7: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/4LnsKghmIO0SXeUL3I20q7
# Error al obtener características de audio para 5LwJdYY3SorVljsVx6J6Uw: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/5LwJdYY3SorVljsVx6J6Uw
# Error al obtener características de audio para 7qVoYh0QN1vZTnlIsDqz3C: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/7qVoYh0QN1vZTnlIsDqz3C
# Error al obtener características de audio para 2UVg1zmnw7ahYu41P6UPaC: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/2UVg1zmnw7ahYu41P6UPaC
# Error al obtener características de audio para 1uoZKu1mDHe1LUsbamdqqU: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/1uoZKu1mDHe1LUsbamdqqU
# Error al obtener características de audio para 71zPpqRMdkEUCl7cPQIBrV: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/71zPpqRMdkEUCl7cPQIBrV
# Error al obtener características de audio para 33LC84JgLvK2KuW43MfaNq: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/33LC84JgLvK2KuW43MfaNq
# Error al obtener características de audio para 7bMrdOiYdHjz5dplqSxj8r: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/7bMrdOiYdHjz5dplqSxj8r
# Error al obtener características de audio para 3cw8eL6EI64aCw9Mw6Ipgd: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/3cw8eL6EI64aCw9Mw6Ipgd
# Error al obtener características de audio para 4Fpsa3pYc3gozrxHRRPvR6: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/4Fpsa3pYc3gozrxHRRPvR6
# Error al obtener características de audio para 1TsAsyHFJZqkuEM26Sg34a: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/1TsAsyHFJZqkuEM26Sg34a
# Error al obtener características de audio para 1eKPBcUKstvi0UKNvpSbl1: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/1eKPBcUKstvi0UKNvpSbl1
# Error al obtener características de audio para 68B311rSsiGSOf35smVmTf: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/68B311rSsiGSOf35smVmTf
# Error al obtener características de audio para 7H2rz79ZSbHWqkBy7U5rAu: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/7H2rz79ZSbHWqkBy7U5rAu
# Error al obtener características de audio para 7H2rz79ZSbHWqkBy7U5rAu: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/7H2rz79ZSbHWqkBy7U5rAu
# Error al obtener características de audio para 2Om6056obklMVh7a0gnKkN: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/2Om6056obklMVh7a0gnKkN
# Error al obtener características de audio para 4Vd3XrtbTMUDTT7UYc0o1F: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/4Vd3XrtbTMUDTT7UYc0o1F
# Error al obtener características de audio para 7H2rz79ZSbHWqkBy7U5rAu: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/7H2rz79ZSbHWqkBy7U5rAu
# Error al obtener características de audio para 5au83jGXgv81PA38HpTdVt: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/5au83jGXgv81PA38HpTdVt
# Error al obtener características de audio para 6Tf1S5hUjxaR3uU6eeY0YS: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/6Tf1S5hUjxaR3uU6eeY0YS
# Error al obtener características de audio para 3g98x0UrsfWzpiRR2gmLtR: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/3g98x0UrsfWzpiRR2gmLtR
# Error al obtener características de audio para 6DfT97NBB9xy0J40eJEU1j: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/6DfT97NBB9xy0J40eJEU1j
# Error al obtener características de audio para 5J43zdQTc8ekUdknGU6c5M: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/5J43zdQTc8ekUdknGU6c5M
# Error al obtener características de audio para 5au83jGXgv81PA38HpTdVt: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/5au83jGXgv81PA38HpTdVt
# Error al obtener características de audio para 56i4MBbcPhYBvn4yc76m20: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/56i4MBbcPhYBvn4yc76m20
# Error al obtener características de audio para 4Fpsa3pYc3gozrxHRRPvR6: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/4Fpsa3pYc3gozrxHRRPvR6
# Error al obtener características de audio para 4mOxpj82q6n3EO7HBZCelX: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/4mOxpj82q6n3EO7HBZCelX
# Error al obtener características de audio para 6qfN0cRXRnOCa7U3ITrRzL: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/6qfN0cRXRnOCa7U3ITrRzL
# Error al obtener características de audio para 4mOxpj82q6n3EO7HBZCelX: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/4mOxpj82q6n3EO7HBZCelX
# Error al obtener características de audio para 2ck13qfgRZ1msyEJlDqzvk: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/2ck13qfgRZ1msyEJlDqzvk
# Error al obtener características de audio para 3ozomn4PrGEKEuusxX2HpC: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/3ozomn4PrGEKEuusxX2HpC
# Error al obtener características de audio para 24SUWisv2lYQiB3bVpE1sn: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/24SUWisv2lYQiB3bVpE1sn
# Error al obtener características de audio para 7ppPZa3TRUSGKaks9wH7VT: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/7ppPZa3TRUSGKaks9wH7VT
# Error al obtener características de audio para 5fKTkCOpnyJko7jZqpbJnX: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/5fKTkCOpnyJko7jZqpbJnX
# Error al obtener características de audio para 0VNXaBd3OuOoopJ0pWYP1y: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/0VNXaBd3OuOoopJ0pWYP1y
# Error al obtener características de audio para 6v2DbCEOjbO4VrNkFACL4k: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/6v2DbCEOjbO4VrNkFACL4k
# Error al obtener características de audio para 1gMFAi2auKTgHsYH7nIBhv: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/1gMFAi2auKTgHsYH7nIBhv
# Error al obtener características de audio para 2QCJcmHByVdv7d5MrGPV63: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/2QCJcmHByVdv7d5MrGPV63
# Error al obtener características de audio para 5Hp8LPFg8DCp5rREjcgswX: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/5Hp8LPFg8DCp5rREjcgswX
# Error al obtener características de audio para 0nLOl4fSiBZKGFla5pLUtf: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/0nLOl4fSiBZKGFla5pLUtf
# Error al obtener características de audio para 6nGUM3Z0FNJZW9wbNj97Ig: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/6nGUM3Z0FNJZW9wbNj97Ig
# Error al obtener características de audio para 5tIwzE936DYfPkvFoeflRO: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/5tIwzE936DYfPkvFoeflRO
# Error al obtener características de audio para 2RzJwBCXsS1VnjDm2jKKAa: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/2RzJwBCXsS1VnjDm2jKKAa
# Error al obtener características de audio para 2RzJwBCXsS1VnjDm2jKKAa: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/2RzJwBCXsS1VnjDm2jKKAa
# Error al obtener características de audio para 5Xr8IX3yREtFpDrzUiiQGD: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/5Xr8IX3yREtFpDrzUiiQGD
# Error al obtener características de audio para 2FK7fxjzQEXD7Z32HSF0Hl: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/2FK7fxjzQEXD7Z32HSF0Hl
# Error al obtener características de audio para 3QHONiXGMGU3z68mQInncF: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/3QHONiXGMGU3z68mQInncF
# Error al obtener características de audio para 5sbN1y7ubvYe2G9LHm7HPz: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/5sbN1y7ubvYe2G9LHm7HPz
# Error al obtener características de audio para 10raF4oJVFSa5CXZayhtGw: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/10raF4oJVFSa5CXZayhtGw
# Error al obtener características de audio para 409SI5Qqm3Zb0Mzk86Cwmz: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/409SI5Qqm3Zb0Mzk86Cwmz
# Error al obtener características de audio para 2KvXtMHWhHjRDMgEC8MJsz: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/2KvXtMHWhHjRDMgEC8MJsz
# Error al obtener características de audio para 7izy5Tt1z9uJQmn8UUZQTw: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/7izy5Tt1z9uJQmn8UUZQTw
# Error al obtener características de audio para 1mwCSKK0YRDsgnj2VwyZSU: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/1mwCSKK0YRDsgnj2VwyZSU
# Error al obtener características de audio para 5zsNrhMNU8qnLqDZNyUPAA: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/5zsNrhMNU8qnLqDZNyUPAA
# Error al obtener características de audio para 3G2UEL40WRcxHcOSHsF4sn: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/3G2UEL40WRcxHcOSHsF4sn
# Error al obtener características de audio para 7L9EFcixaIOGjrh71XN4wZ: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/7L9EFcixaIOGjrh71XN4wZ
# Error al obtener características de audio para 6TKrFeYMaMVcF6Ca4yTYzD: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/6TKrFeYMaMVcF6Ca4yTYzD
# Error al obtener características de audio para 13efPu5TlBN9X9oOo9ItBv: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/13efPu5TlBN9X9oOo9ItBv
# Error al obtener características de audio para 5lsR6wuL7T7vR5IOZwPaEc: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/5lsR6wuL7T7vR5IOZwPaEc
# Error al obtener características de audio para 1CUfayodt9vpUK33F87GEj: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/1CUfayodt9vpUK33F87GEj
# Error al obtener características de audio para 4zAjQDduJhIRFSpfrIN68Z: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/4zAjQDduJhIRFSpfrIN68Z
# Error al obtener características de audio para 0VFLz9b1V4kThYPLycVMoT: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/0VFLz9b1V4kThYPLycVMoT
# Error al obtener características de audio para 2zTYTgsrmsKlI8mLp9oBNe: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/2zTYTgsrmsKlI8mLp9oBNe
# Error al obtener características de audio para 1INKoD3iLAGucA61tkCEJt: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/1INKoD3iLAGucA61tkCEJt
# Error al obtener características de audio para 26tWBbtjvgi0tipRL2VQ2X: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/26tWBbtjvgi0tipRL2VQ2X
# Información rellenada en fila 2500
# Error al obtener características de audio para 58b4jrSFpBMXdNFZFGPbrj: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/58b4jrSFpBMXdNFZFGPbrj
# Error al obtener características de audio para 5lI2KuMlOrQdkzU66DeaPQ: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/5lI2KuMlOrQdkzU66DeaPQ
# Error al obtener características de audio para 2lDcq6gFN9W5yXHk0NU7ve: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/2lDcq6gFN9W5yXHk0NU7ve
# Error al obtener características de audio para 7dniUnDWDCZn9V7iT2dAhl: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/7dniUnDWDCZn9V7iT2dAhl
# Error al obtener características de audio para 7ppPZa3TRUSGKaks9wH7VT: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/7ppPZa3TRUSGKaks9wH7VT
# Error al obtener características de audio para 6kqXaZrIDOmA177KL9LHHf: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/6kqXaZrIDOmA177KL9LHHf
# Error al obtener características de audio para 2nZFHHHFgrxCDrkdW8RYpo: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/2nZFHHHFgrxCDrkdW8RYpo
# Error al obtener características de audio para 6qfN0cRXRnOCa7U3ITrRzL: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/6qfN0cRXRnOCa7U3ITrRzL
# Error al obtener características de audio para 0PFSM5mQDrKkhBbKPfXCk4: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/0PFSM5mQDrKkhBbKPfXCk4
# Error al obtener características de audio para 5KYmWoLE2qFL55eNr5L8G0: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/5KYmWoLE2qFL55eNr5L8G0
# Error al obtener características de audio para 0uAyeKNw5WGU1nWNlbvY1Q: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/0uAyeKNw5WGU1nWNlbvY1Q
# Error al obtener características de audio para 1ZsJdeKS6c7zCXGPi4AXKw: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/1ZsJdeKS6c7zCXGPi4AXKw
# Error al obtener características de audio para 7gKHQy915DlMWd1xuF11BO: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/7gKHQy915DlMWd1xuF11BO
# Error al obtener características de audio para 5xSGesrfP1OufW855AZb8x: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/5xSGesrfP1OufW855AZb8x
# Error al obtener características de audio para 53JuszD36WgJTr4Rdq7kjO: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/53JuszD36WgJTr4Rdq7kjO
# Error al obtener características de audio para 3nAuX0TA8yhqsPDHO8ybFe: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/3nAuX0TA8yhqsPDHO8ybFe
# Error al obtener características de audio para 1dfHmxDdBI6So6IH5tnBqo: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/1dfHmxDdBI6So6IH5tnBqo
# Error al obtener características de audio para 28RQFtMSNzRLAlXjIjVLsC: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/28RQFtMSNzRLAlXjIjVLsC
# Error al obtener características de audio para 5YU6hZPrbVdbBYnS7xK7ma: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/5YU6hZPrbVdbBYnS7xK7ma
# Error al obtener características de audio para 6YYu8qFzcY1ZyzzsJIQM12: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/6YYu8qFzcY1ZyzzsJIQM12
# Error al obtener características de audio para 6bajdlezalKY3BsnwlGNc7: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/6bajdlezalKY3BsnwlGNc7
# Error al obtener características de audio para 140scP0VNGctWwKOIzGF0L: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/140scP0VNGctWwKOIzGF0L
# Error al obtener características de audio para 3sLhMSePzxSrmxluIqeoAZ: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/3sLhMSePzxSrmxluIqeoAZ
# Error al obtener características de audio para 5NB1tkBjBeEJoto2qWbmXU: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/5NB1tkBjBeEJoto2qWbmXU
# Error al obtener características de audio para 5NB1tkBjBeEJoto2qWbmXU: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/5NB1tkBjBeEJoto2qWbmXU
# Error al obtener características de audio para 0VNXaBd3OuOoopJ0pWYP1y: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/0VNXaBd3OuOoopJ0pWYP1y
# Error al obtener características de audio para 2ezqQeBiC72gwMJoO4w1hA: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/2ezqQeBiC72gwMJoO4w1hA
# Error al obtener características de audio para 294IzNQIRp4soeVaQhows7: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/294IzNQIRp4soeVaQhows7
# Error al obtener características de audio para 3eLTSI4vKo5mUF12oVQnlH: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/3eLTSI4vKo5mUF12oVQnlH
# Error al obtener características de audio para 7uIigpppp7R38g1d3vugw3: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/7uIigpppp7R38g1d3vugw3
# Error al obtener características de audio para 0chObh71oD0pYijuxNSU5S: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/0chObh71oD0pYijuxNSU5S
# Error al obtener características de audio para 2zlXHef13RgvroaboeAYfN: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/2zlXHef13RgvroaboeAYfN
# Error al obtener características de audio para 3eLTSI4vKo5mUF12oVQnlH: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/3eLTSI4vKo5mUF12oVQnlH
# Error al obtener características de audio para 2t7tEp9DkfCVbPi23QwwJT: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/2t7tEp9DkfCVbPi23QwwJT
# Error al obtener características de audio para 0o3Mcv1JOPsrnc3wBROq2S: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/0o3Mcv1JOPsrnc3wBROq2S
# Error al obtener características de audio para 2QBm09M5XJJxN5JJMQkXwN: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/2QBm09M5XJJxN5JJMQkXwN
# Error al obtener características de audio para 0aXotRwEox6V6DUaczAeUH: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/0aXotRwEox6V6DUaczAeUH
# Error al obtener características de audio para 4RqjrEjWyJMuyIIWjO2eF1: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/4RqjrEjWyJMuyIIWjO2eF1
# Error al obtener características de audio para 6a62Uu7QyI1YiQ0KIBe8GM: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/6a62Uu7QyI1YiQ0KIBe8GM
# Error al obtener características de audio para 5Ds0VGkTSQ1jf4KzLUpZPb: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/5Ds0VGkTSQ1jf4KzLUpZPb
# Error al obtener características de audio para 5EQzuYfTZt7B2LqlvTF49l: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/5EQzuYfTZt7B2LqlvTF49l
# Error al obtener características de audio para 5Ds0VGkTSQ1jf4KzLUpZPb: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/5Ds0VGkTSQ1jf4KzLUpZPb
# Error al obtener características de audio para 5Ihd9HrPvOADyVoonH9ZjB: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/5Ihd9HrPvOADyVoonH9ZjB
# Error al obtener características de audio para 5Ds0VGkTSQ1jf4KzLUpZPb: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/5Ds0VGkTSQ1jf4KzLUpZPb
# Error al obtener características de audio para 6hLY3Tz1Xt5kBuKNDTs4ib: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/6hLY3Tz1Xt5kBuKNDTs4ib
# Error al obtener características de audio para 6s6h2XK7Nl8lEcTzr7ezeB: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/6s6h2XK7Nl8lEcTzr7ezeB
# Error al obtener características de audio para 2jWuNKBlgkfb3M0WDKexY8: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/2jWuNKBlgkfb3M0WDKexY8
# Error al obtener características de audio para 5EQzuYfTZt7B2LqlvTF49l: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/5EQzuYfTZt7B2LqlvTF49l
# Error al obtener características de audio para 5jGWwfmve3p9h26ujnEmwq: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/5jGWwfmve3p9h26ujnEmwq
# Error al obtener características de audio para 5XrfFo0JFOnWD9ZMNXGkQh: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/5XrfFo0JFOnWD9ZMNXGkQh
# Error al obtener características de audio para 3IQu6EQqPlYN3pk0xQz9zK: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/3IQu6EQqPlYN3pk0xQz9zK
# Error al obtener características de audio para 5NLUcVnVHfnkt4uUexWdIH: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/5NLUcVnVHfnkt4uUexWdIH
# Error al obtener características de audio para 22AYE62irnblz8OMUzz6Qi: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/22AYE62irnblz8OMUzz6Qi
# Error al obtener características de audio para 5tysS4cVvS0zeCLTBI0VQr: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/5tysS4cVvS0zeCLTBI0VQr
# Error al obtener características de audio para 4vDBJeeQCbhP9FaPPMsYkY: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/4vDBJeeQCbhP9FaPPMsYkY
# Error al obtener características de audio para 2Z5ybF5xXLAd9ZOepA2Mve: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/2Z5ybF5xXLAd9ZOepA2Mve
# Error al obtener características de audio para 5bJ796cOnGBzSN5bm4mwMj: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/5bJ796cOnGBzSN5bm4mwMj
# Error al obtener características de audio para 56JRqiQ6QRaehxkG8852pL: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/56JRqiQ6QRaehxkG8852pL
# Error al obtener características de audio para 0Q0IVlqMV64kNLlwjPj0Hl: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/0Q0IVlqMV64kNLlwjPj0Hl
# Error al obtener características de audio para 1X3ypzPnyerpZuMqrDFK29: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/1X3ypzPnyerpZuMqrDFK29
# Error al obtener características de audio para 0bhwnn2xqnBUcMZDcXNuII: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/0bhwnn2xqnBUcMZDcXNuII
# Error al obtener características de audio para 5KSJ9k1FYjFLnIRlJT2wF8: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/5KSJ9k1FYjFLnIRlJT2wF8
# Error al obtener características de audio para 6wJYhPfqk3KGhHRG76WzOh: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/6wJYhPfqk3KGhHRG76WzOh
# Error al obtener características de audio para 5rbyo0w2SUKV8P4UObcarM: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/5rbyo0w2SUKV8P4UObcarM
# Error al obtener características de audio para 09qzRI951OVkXGCc33gzcT: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/09qzRI951OVkXGCc33gzcT
# Error al obtener características de audio para 0rCpM4RAr8FzYhAR5jryDQ: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/0rCpM4RAr8FzYhAR5jryDQ
# Error al obtener características de audio para 0jKTbJXXD8TD6Ueu180u6A: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/0jKTbJXXD8TD6Ueu180u6A
# Error al obtener características de audio para 6wJYhPfqk3KGhHRG76WzOh: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/6wJYhPfqk3KGhHRG76WzOh
# Error al obtener características de audio para 2BfWqUcVspnvCSEtGhsIoA: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/2BfWqUcVspnvCSEtGhsIoA
# Error al obtener características de audio para 1EYTsenPJf1uFS4AGg09HN: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/1EYTsenPJf1uFS4AGg09HN
# Error al obtener características de audio para 5kKhYu3EfmwuOFjMp4IQcG: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/5kKhYu3EfmwuOFjMp4IQcG
# Error al obtener características de audio para 098ttCNmncrO4YvqWUNMvn: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/098ttCNmncrO4YvqWUNMvn
# Error al obtener características de audio para 21HsI1RpRHEjbUjmzHtIyj: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/21HsI1RpRHEjbUjmzHtIyj
# Error al obtener características de audio para 5cCpq6EJqI8dgz8FwE7gk3: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/5cCpq6EJqI8dgz8FwE7gk3
# Error al obtener características de audio para 3qf5hNUHntfOl8UTRiYWWc: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/3qf5hNUHntfOl8UTRiYWWc
# Error al obtener características de audio para 25uhgGKZCzGSYqedJH39sJ: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/25uhgGKZCzGSYqedJH39sJ
# Error al obtener características de audio para 2yRhZBLMH9HN5yPdFaIKyP: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/2yRhZBLMH9HN5yPdFaIKyP
# Error al obtener características de audio para 5ID6qIRs04r4fMajBDY7uK: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/5ID6qIRs04r4fMajBDY7uK
# ...
# Error al obtener características de audio para 2fT8tRML4PUZa1cZZ5bPZz: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/2fT8tRML4PUZa1cZZ5bPZz
# Error al obtener características de audio para 04sdV2cJysM7qES6DwdLu9: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/04sdV2cJysM7qES6DwdLu9
# Error al obtener características de audio para 2fT8tRML4PUZa1cZZ5bPZz: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/2fT8tRML4PUZa1cZZ5bPZz
# Error al obtener características de audio para 7vuVvDFhHH3h7QyLMagBoB: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/7vuVvDFhHH3h7QyLMagBoB
# Error al obtener características de audio para 5zPMzOLIyKspjGM3nRa7zy: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/5zPMzOLIyKspjGM3nRa7zy
# Error al obtener características de audio para 2SrXt0JJEX9PfVSZuJ6dqg: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/2SrXt0JJEX9PfVSZuJ6dqg
# Error al obtener características de audio para 7udrxkpUGUGf1wTHWHpIOy: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/7udrxkpUGUGf1wTHWHpIOy
# Error al obtener características de audio para 726OIMOZ6uDlvGsdUbbazS: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/726OIMOZ6uDlvGsdUbbazS
# Error al obtener características de audio para 2SrXt0JJEX9PfVSZuJ6dqg: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/2SrXt0JJEX9PfVSZuJ6dqg
# Error al obtener características de audio para 02NKMA9cIkq6VuBNu9q9Wf: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/02NKMA9cIkq6VuBNu9q9Wf
# Error al obtener características de audio para 2qLxtO0iaFGI9x19vU3bDI: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/2qLxtO0iaFGI9x19vU3bDI
# Error al obtener características de audio para 04sdV2cJysM7qES6DwdLu9: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/04sdV2cJysM7qES6DwdLu9
# Error al obtener características de audio para 1xMR4PVTrmhzvze2L0pUMj: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/1xMR4PVTrmhzvze2L0pUMj
# Error al obtener características de audio para 02NKMA9cIkq6VuBNu9q9Wf: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/02NKMA9cIkq6VuBNu9q9Wf
# Error al obtener características de audio para 6Hqz1Mm5BavbzPIPFEhT55: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/6Hqz1Mm5BavbzPIPFEhT55
# Error al obtener características de audio para 0UYnhUfnUj5adChuAXvLUB: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/0UYnhUfnUj5adChuAXvLUB
# Error al obtener características de audio para 4irwVRtTfHk4imKxoRYh9K: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/4irwVRtTfHk4imKxoRYh9K
# Error al obtener características de audio para 02NKMA9cIkq6VuBNu9q9Wf: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/02NKMA9cIkq6VuBNu9q9Wf
# Error al obtener características de audio para 77Wd16X526TPJhNLZLvWQJ: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/77Wd16X526TPJhNLZLvWQJ
# Error al obtener características de audio para 0LNlOQJ2NQsLLZWshogfSI: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/0LNlOQJ2NQsLLZWshogfSI
# Error al obtener características de audio para 6Kv5Wh4zu18gKmwTWx523Y: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/6Kv5Wh4zu18gKmwTWx523Y
# Error al obtener características de audio para 2ZjhhB3kZP6Zufmjuv2TWC: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/2ZjhhB3kZP6Zufmjuv2TWC
# Error al obtener características de audio para 2t2MNUMRpFgeScAGNFGsNa: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/2t2MNUMRpFgeScAGNFGsNa
# Error al obtener características de audio para 1QYpCrXkzS4tb40lbXQZUH: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/audio-features/1QYpCrXkzS4tb40lbXQZUH
# Conteo de NaN después del proceso:
# id                 1
# year               1
# title              1
# category           1
# nominee            1
# artist             1
# workers            1
# winner             1
# spotify_id         1
# Unnamed: 0      4222
# track_id           3
# artists            3
# album_name         3
# track_name         3
# popularity         3
# duration_ms        3
# danceability    2221
# energy          2221
# tempo           2221
# track_genre     4222
# dtype: int64
#         id    year                              title  \
# 0      1.0  2019.0  62nd Annual GRAMMY Awards  (2019)
# 1      2.0  2019.0  62nd Annual GRAMMY Awards  (2019)
# 2      3.0  2019.0  62nd Annual GRAMMY Awards  (2019)
# 3      4.0  2019.0  62nd Annual GRAMMY Awards  (2019)
# 4      5.0  2019.0  62nd Annual GRAMMY Awards  (2019)
# 5      6.0  2019.0  62nd Annual GRAMMY Awards  (2019)
# 6      7.0  2019.0  62nd Annual GRAMMY Awards  (2019)
# 7      8.0  2019.0  62nd Annual GRAMMY Awards  (2019)
# 8      9.0  2019.0  62nd Annual GRAMMY Awards  (2019)
# 9     10.0  2019.0  62nd Annual GRAMMY Awards  (2019)
# 10    11.0  2019.0  62nd Annual GRAMMY Awards  (2019)
# 11    12.0  2019.0  62nd Annual GRAMMY Awards  (2019)
# 12    13.0  2019.0  62nd Annual GRAMMY Awards  (2019)
# 13    14.0  2019.0  62nd Annual GRAMMY Awards  (2019)
# 14    15.0  2019.0  62nd Annual GRAMMY Awards  (2019)
# 15    16.0  2019.0  62nd Annual GRAMMY Awards  (2019)
# 16    17.0  2019.0  62nd Annual GRAMMY Awards  (2019)
# 17    18.0  2019.0  62nd Annual GRAMMY Awards  (2019)
# 18  3354.0  1987.0  30th Annual GRAMMY Awards  (1987)
# 19    19.0  2019.0  62nd Annual GRAMMY Awards  (2019)
#
#                                  category  \
# 0                      Record Of The Year
# 1                      Record Of The Year
# 2                      Record Of The Year
# 3                      Record Of The Year
# 4                      Record Of The Year
# 5                      Record Of The Year
# 6                      Record Of The Year
# 7                      Record Of The Year
# 8                       Album Of The Year
# 9                       Album Of The Year
# 10                      Album Of The Year
# 11                      Album Of The Year
# 12                      Album Of The Year
# 13                      Album Of The Year
# 14                      Album Of The Year
# 15                      Album Of The Year
# 16                       Song Of The Year
# 17                       Song Of The Year
# 18  Producer Of The Year, (Non Classical)
# 19                       Song Of The Year
#
#                                      nominee  \
# 0                                    Bad Guy
# 1                                    Hey, Ma
# 2                                    7 rings
# 3                                 Hard Place
# 4                                       Talk
# 5                              Old Town Road
# 6                                Truth Hurts
# 7                                  Sunflower
# 8   When We All Fall Asleep, Where Do We Go?
# 9                                        I,I
# 10                  Norman F***ing Rockwell!
# 11                             thank u, next
# 12                        I Used To Know Her
# 13                                         7
# 14                   Cuz I Love You (Deluxe)
# 15                       Father Of The Bride
# 16                                   Bad Guy
# 17               Always Remember Us This Way
# 18                     Narada Michael Walden
# 19                      Bring My Flowers Now
#
#                                  artist  \
# 0                         Billie Eilish
# 1                              Bon Iver
# 2                         Ariana Grande
# 3                                H.E.R.
# 4                                Khalid
# 5   Lil Nas X Featuring Billy Ray Cyrus
# 6                                 Lizzo
# 7                Post Malone & Swae Lee
# 8                         Billie Eilish
# 9                              Bon Iver
# 10                         Lana Del Rey
# 11                        Ariana Grande
# 12                               H.E.R.
# 13                            Lil Nas X
# 14                                Lizzo
# 15                      Vampire Weekend
# 16                        Billie Eilish
# 17                            Lady Gaga
# 18                Narada Michael Walden
# 19                         Tanya Tucker
#
#                                               workers winner  \
# 0   Finneas O'Connell, producer; Rob Kinelski & Fi...   True
# 1   BJ Burton, Brad Cook, Chris Messina & Justin V...   True
# 2   Charles Anderson, Tommy Brown, Michael Foster ...   True
# 3   Rodney “Darkchild” Jerkins, producer; Joseph H...   True
# 4   Disclosure & Denis Kosiak, producers; Ingmar C...   True
# 5   Andrew "VoxGod" Bolooki, Jocelyn “Jozzy” Donal...   True
# 6   Ricky Reed & Tele, producers; Chris Galland, M...   True
# 7   Louis Bell & Carter Lang, producers; Louis Bel...   True
# 8   Finneas O'Connell, producer; Rob Kinelski & Fi...   True
# 9   Brad Cook, Chris Messina & Justin Vernon, prod...   True
# 10  Jack Antonoff & Lana Del Rey, producers; Jack ...   True
# 11  Tommy Brown, Ilya, Max Martin & Victoria Monet...   True
# 12  David "Swagg R'Celious" Harris, H.E.R., Walter...   True
# 13  Joe Grasso, engineer/mixer; Montero Lamar Hill...   True
# 14  Ricky Reed, producer; Manny Marroquin & Ethan ...   True
# 15  Ezra Koenig & Ariel Rechtshaid, producers; Joh...   True
# 16  Billie Eilish O'Connell & Finneas O'Connell, s...   True
# 17  Natalie Hemby, Lady Gaga, Hillary Lindsey & Lo...   True
# 18                                     unknown worker   True
# 19  Brandi Carlile, Phil Hanseroth, Tim Hanseroth ...   True
#
#                 spotify_id  Unnamed: 0                track_id  \
# 0   2Fxmhks0bxGSBdJ92vM42m     31018.0  2Fxmhks0bxGSBdJ92vM42m
# 1   0RstfX9nRY1Lfuy1808MoT         NaN  0RstfX9nRY1Lfuy1808MoT
# 2   6ocbgoVGwYJhOv1GgI9NsF     20009.0  6ocbgoVGwYJhOv1GgI9NsF
# 3   4IablJ6SqVNGY4vrseyKxu         NaN  4IablJ6SqVNGY4vrseyKxu
# 4   6g6A7qNhTfUgOSH7ROOxTD         NaN  6g6A7qNhTfUgOSH7ROOxTD
# 5   0F7FA14euOIX8KcbEturGH     51251.0  0F7FA14euOIX8KcbEturGH
# 6   3HWzoMvoF3TQfYg4UPszDq         NaN  3HWzoMvoF3TQfYg4UPszDq
# 7   3KkXRkHbMCARz0aVfEt68P         NaN  3KkXRkHbMCARz0aVfEt68P
# 8   43zdsphuZLzwA9k4DJhU0I         NaN  43zdsphuZLzwA9k4DJhU0I
# 9   3ihJ79kKH1P3YrOznRSDIA         NaN  3ihJ79kKH1P3YrOznRSDIA
# 10  3RIgHHpnFKj5Rni1shokDj         NaN  3RIgHHpnFKj5Rni1shokDj
# 11  3e9HZxeyfWwjeyPAMmWSSQ     20303.0  3e9HZxeyfWwjeyPAMmWSSQ
# 12  6oEVnWKgPqIEPc53OYDNqG         NaN  6oEVnWKgPqIEPc53OYDNqG
# 13  5kqIPrATaCc2LqxVWzQGbk         NaN  5kqIPrATaCc2LqxVWzQGbk
# 14  3HWzoMvoF3TQfYg4UPszDq         NaN  3HWzoMvoF3TQfYg4UPszDq
# 15  39exKIvycQDgs4T6uXdyu0         NaN  39exKIvycQDgs4T6uXdyu0
# 16  2Fxmhks0bxGSBdJ92vM42m     31018.0  2Fxmhks0bxGSBdJ92vM42m
# 17  2rbDhOo9Fh61Bbu23T2qCk         NaN  2rbDhOo9Fh61Bbu23T2qCk
# 18  0PjkD419FrFnRuS5Mgs6pm         NaN  0PjkD419FrFnRuS5Mgs6pm
# 19  7nx130yomv3fvvFD0fcGOG         NaN  7nx130yomv3fvvFD0fcGOG
#
#                    artists                                         album_name  \
# 0            Billie Eilish           WHEN WE ALL FALL ASLEEP, WHERE DO WE GO?
# 1                 Bon Iver                                                i,i
# 2            Ariana Grande                                      thank u, next
# 3                   H.E.R.                                         Hard Place
# 4   Jason Derulo, 2 Chainz                                         Talk Dirty
# 5                Lil Nas X                                               7 EP
# 6                    Lizzo                      Cuz I Love You (Super Deluxe)
# 7    Post Malone, Swae Lee  Spider-Man: Into the Spider-Verse (Soundtrack ...
# 8            Billie Eilish           WHEN WE ALL FALL ASLEEP, WHERE DO WE GO?
# 9           Lovejoy Street                                         Exit Signs
# 10            Lana Del Rey                           Norman Fucking Rockwell!
# 11           Ariana Grande                                      thank u, next
# 12   H.E.R., Bryson Tiller                                 I Used To Know Her
# 13            Lukas Graham                                       Lukas Graham
# 14                   Lizzo                      Cuz I Love You (Super Deluxe)
# 15         Vampire Weekend                                Father of the Bride
# 16           Billie Eilish           WHEN WE ALL FALL ASLEEP, WHERE DO WE GO?
# 17               Lady Gaga       A Star Is Born Soundtrack (Without Dialogue)
# 18   Narada Michael Walden                                  The Dance Of Life
# 19            Tanya Tucker                                   While I'm Livin'
#
#                                        track_name  popularity  duration_ms  \
# 0                                         bad guy        84.0     194087.0
# 1                                         Hey, Ma        58.0     216706.0
# 2                                         7 rings        84.0     178626.0
# 3                                      Hard Place        54.0     271733.0
# 4                     Talk Dirty (feat. 2 Chainz)        67.0     177685.0
# 5                                   Old Town Road        77.0     113000.0
# 6                                     Truth Hurts        70.0     173325.0
# 7   Sunflower - Spider-Man: Into the Spider-Verse        80.0     158040.0
# 8                           when the party's over        83.0     196077.0
# 9                                             I,I         0.0     185251.0
# 10                        Norman fucking Rockwell        73.0     248934.0
# 11                                  thank u, next        82.0     207320.0
# 12            Could've Been (feat. Bryson Tiller)        75.0     252746.0
# 13                                        7 Years        81.0     237300.0
# 14                                    Truth Hurts        70.0     173325.0
# 15                                   Harmony Hall        59.0     308733.0
# 16                                        bad guy        84.0     194087.0
# 17                    Always Remember Us This Way        83.0     210200.0
# 18                             I Shoulda Loved Ya        36.0     397133.0
# 19                           Bring My Flowers Now        34.0     260360.0
#
#     danceability  energy    tempo track_genre
# 0          0.701   0.425  135.128     electro
# 1          0.325   0.286  144.296        None
# 2          0.778   0.317  140.048       dance
# 3          0.614   0.719  160.075        None
# 4          0.760   0.652  100.315        None
# 5          0.907   0.530  135.998     hip-hop
# 6          0.715   0.624  158.087        None
# 7          0.760   0.478   89.908        None
# 8          0.367   0.111   82.642        None
# 9          0.568   0.709  106.040        None
# 10         0.215   0.203   78.287        None
# 11         0.717   0.653  106.966       dance
# 12         0.450   0.352  102.679        None
# 13         0.765   0.473  119.992        None
# 14         0.715   0.624  158.087        None
# 15         0.653   0.760   98.008        None
# 16         0.701   0.425  135.128     electro
# 17         0.549   0.502  129.842        None
# 18         0.759   0.598  113.807        None
# 19         0.557   0.198  133.823        None

# %%
# Opcional: Verificar las primeras filas del DataFrame limpio
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
final_merged_df.head(5)
# Out:
#     id    year                              title            category  \
# 0  1.0  2019.0  62nd Annual GRAMMY Awards  (2019)  Record Of The Year
# 1  2.0  2019.0  62nd Annual GRAMMY Awards  (2019)  Record Of The Year
# 2  3.0  2019.0  62nd Annual GRAMMY Awards  (2019)  Record Of The Year
# 3  4.0  2019.0  62nd Annual GRAMMY Awards  (2019)  Record Of The Year
# 4  5.0  2019.0  62nd Annual GRAMMY Awards  (2019)  Record Of The Year
#
#       nominee         artist  \
# 0     Bad Guy  Billie Eilish
# 1     Hey, Ma       Bon Iver
# 2     7 rings  Ariana Grande
# 3  Hard Place         H.E.R.
# 4        Talk         Khalid
#
#                                              workers winner  \
# 0  Finneas O'Connell, producer; Rob Kinelski & Fi...   True
# 1  BJ Burton, Brad Cook, Chris Messina & Justin V...   True
# 2  Charles Anderson, Tommy Brown, Michael Foster ...   True
# 3  Rodney “Darkchild” Jerkins, producer; Joseph H...   True
# 4  Disclosure & Denis Kosiak, producers; Ingmar C...   True
#
#                spotify_id  Unnamed: 0                track_id  \
# 0  2Fxmhks0bxGSBdJ92vM42m     31018.0  2Fxmhks0bxGSBdJ92vM42m
# 1  0RstfX9nRY1Lfuy1808MoT         NaN  0RstfX9nRY1Lfuy1808MoT
# 2  6ocbgoVGwYJhOv1GgI9NsF     20009.0  6ocbgoVGwYJhOv1GgI9NsF
# 3  4IablJ6SqVNGY4vrseyKxu         NaN  4IablJ6SqVNGY4vrseyKxu
# 4  6g6A7qNhTfUgOSH7ROOxTD         NaN  6g6A7qNhTfUgOSH7ROOxTD
#
#                   artists                                album_name  \
# 0           Billie Eilish  WHEN WE ALL FALL ASLEEP, WHERE DO WE GO?
# 1                Bon Iver                                       i,i
# 2           Ariana Grande                             thank u, next
# 3                  H.E.R.                                Hard Place
# 4  Jason Derulo, 2 Chainz                                Talk Dirty
#
#                     track_name  popularity  duration_ms  danceability  energy  \
# 0                      bad guy        84.0     194087.0         0.701   0.425
# 1                      Hey, Ma        58.0     216706.0         0.325   0.286
# 2                      7 rings        84.0     178626.0         0.778   0.317
# 3                   Hard Place        54.0     271733.0         0.614   0.719
# 4  Talk Dirty (feat. 2 Chainz)        67.0     177685.0         0.760   0.652
#
#      tempo track_genre
# 0  135.128     electro
# 1  144.296        None
# 2  140.048       dance
# 3  160.075        None
# 4  100.315        None

# %%
# Guardar el resultado actualizado en un nuevo archivo CSV (opcional)
output_path = r'C:\Users\USUARIO\Documents\Workshop2\notebooks\Merged_Updated.csv'
final_merged_df.to_csv(output_path, index=False)
print(f"Archivo actualizado guardado en: {output_path}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 # Guardar el resultado actualizado en un nuevo archivo CSV (opcional)
#       2 output_path = r'C:\Users\USUARIO\Documents\Workshop2\notebooks\Merged_Updated.csv'
# ----> 3 final_merged_df.to_csv(output_path, index=False)
#       4 print(f"Archivo actualizado guardado en: {output_path}")
#
# NameError: name 'final_merged_df' is not defined

# %%
# Excluir las columnas 'Unnamed: 0' y 'track_genre' al verificar NaN
columns_to_exclude = ['Unnamed: 0', 'track_genre']
filtered_df = final_merged_df.drop(columns=columns_to_exclude, errors='ignore')

# Ver el número total de filas y columnas en el DataFrame (sin excluir columnas)
total_filas, total_columnas = final_merged_df.shape
print(f"Total de filas: {total_filas}")
print(f"Total de columnas: {total_columnas}")

# Ver cuántas filas tienen NaN en alguna columna (excluyendo las columnas especificadas)
filas_con_nan = filtered_df.isna().any(axis=1).sum()
print(f"Filas con valores NaN (excluyendo 'Unnamed: 0' y 'track_genre'): {filas_con_nan}")

# Ver cuántas columnas tienen al menos un NaN (excluyendo las columnas especificadas)
columnas_con_nan = filtered_df.isna().any(axis=0).sum()
print(f"Columnas con valores NaN (excluyendo 'Unnamed: 0' y 'track_genre'): {columnas_con_nan}")
# Out:
# Total de filas: 4757
# Total de columnas: 20
# Filas con valores NaN (excluyendo 'Unnamed: 0' y 'track_genre'): 2222
# Columnas con valores NaN (excluyendo 'Unnamed: 0' y 'track_genre'): 18

# %%
# Excluir las columnas 'Unnamed: 0' y 'track_genre' al verificar NaN
columns_to_exclude = ['Unnamed: 0', 'track_genre','danceability','energy','tempo']
filtered_df = final_merged_df.drop(columns=columns_to_exclude, errors='ignore')

# Ver el número total de filas y columnas en el DataFrame (sin excluir columnas)
total_filas, total_columnas = final_merged_df.shape
print(f"Total de filas: {total_filas}")
print(f"Total de columnas: {total_columnas}")

# Ver cuántas filas tienen NaN en alguna columna (excluyendo las columnas especificadas)
filas_con_nan = filtered_df.isna().any(axis=1).sum()
print(f"Filas con valores NaN (excluyendo 'Unnamed: 0' ,'track_genre' ,'danceability','energy'y'tempo'): {filas_con_nan}")

# Ver cuántas columnas tienen al menos un NaN (excluyendo las columnas especificadas)
columnas_con_nan = filtered_df.isna().any(axis=0).sum()
print(f"Columnas con valores NaN (excluyendo 'Unnamed: 0' y 'track_genre','danceability','energy'y'tempo'): {columnas_con_nan}")
# Out:
# Total de filas: 4757
# Total de columnas: 20
# Filas con valores NaN (excluyendo 'Unnamed: 0' ,'track_genre' ,'danceability','energy'y'tempo'): 4
# Columnas con valores NaN (excluyendo 'Unnamed: 0' y 'track_genre','danceability','energy'y'tempo'): 15

# %%
# Filtrar las filas que contienen NaN (excluyendo 'Unnamed: 0' y 'track_genre')
filas_con_nan_df = filtered_df[filtered_df.isna().any(axis=1)]

# Mostrar las primeras 10 filas que tienen NaN
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
filas_con_nan_df.head(10)
# Out:
#           id    year                              title  \
# 383    382.0  2019.0  62nd Annual GRAMMY Awards  (2019)
# 2300  2316.0  1999.0  42nd Annual GRAMMY Awards  (1999)
# 2301  2317.0  1999.0  42nd Annual GRAMMY Awards  (1999)
# 2302  2318.0  1999.0  42nd Annual GRAMMY Awards  (1999)
# 2303  2319.0  1999.0  42nd Annual GRAMMY Awards  (1999)
# 2304  2320.0  1999.0  42nd Annual GRAMMY Awards  (1999)
# 2305  2321.0  1999.0  42nd Annual GRAMMY Awards  (1999)
# 2306  2322.0  1999.0  42nd Annual GRAMMY Awards  (1999)
# 2307  2323.0  1999.0  42nd Annual GRAMMY Awards  (1999)
# 2308  2324.0  1999.0  42nd Annual GRAMMY Awards  (1999)
#
#                                                category  \
# 383                     Producer Of The Year, Classical
# 2300                                 Best New Age Album
# 2301                 Best Contemporary Jazz Performance
# 2302                        Best Jazz Vocal Performance
# 2303                        Best Jazz Instrumental Solo
# 2304  Best Jazz Instrumental Performance, Individual...
# 2305               Best Large Jazz Ensemble Performance
# 2306                        Best Latin Jazz Performance
# 2307                             Best Rock Gospel Album
# 2308                 Best Pop/Contemporary Gospel Album
#
#                        nominee  \
# 383               Dirk Sobotka
# 2300           Celtic Solstice
# 2301                    Inside
# 2302  When I Look In Your Eyes
# 2303           In Walked Wayne
# 2304                Like Minds
# 2305            Serendipity 18
# 2306                Latin Soul
# 2307                      Pray
# 2308                Speechless
#
#                                                  artist  \
# 383                                    Artist Not Found
# 2300                              Paul Winter & Friends
# 2301                                      David Sanborn
# 2302                                        Diana Krall
# 2303                                       J.J. Johnson
# 2304  Gary Burton, Chick Corea, Pat Metheny, Roy Hay...
# 2305                   The Bob Florence Limited Edition
# 2306                                     Poncho Sanchez
# 2307                                  Rebecca St. James
# 2308                              Steven Curtis Chapman
#
#                                                 workers winner  \
# 383   • Bruckner: Symphony No. 9 (Manfred Honeck & P...   True
# 2300                                     unknown worker   True
# 2301                                     unknown worker   True
# 2302                                     unknown worker   True
# 2303                             Wayne Shorter, soloist   True
# 2304                                     unknown worker   True
# 2305                                     unknown worker   True
# 2306                                     unknown worker   True
# 2307                                     unknown worker   True
# 2308                                     unknown worker   True
#
#                   spotify_id                track_id  \
# 383   65PQMTZdPm2YjRLmcC5OJA                     NaN
# 2300  5IgX3rn7NTdtuuMwe0lytM  5IgX3rn7NTdtuuMwe0lytM
# 2301  4J4Yx1ev1og69BKMtKVERL  4J4Yx1ev1og69BKMtKVERL
# 2302  4IVyX0UJzGyUk0MLiz1jVJ  4IVyX0UJzGyUk0MLiz1jVJ
# 2303  1ukyoZde6M7HdoH0xGE3nB  1ukyoZde6M7HdoH0xGE3nB
# 2304  3WLDpY3HK7d7ezz28257Y2  3WLDpY3HK7d7ezz28257Y2
# 2305  7n14OIikBlKLOqLdECn1SP  7n14OIikBlKLOqLdECn1SP
# 2306  1pjXQaJXYUUz3NMd8Z7lt8  1pjXQaJXYUUz3NMd8Z7lt8
# 2307  77UjLW8j5UAGAGVGhR5oUK  77UjLW8j5UAGAGVGhR5oUK
# 2308  0XPsOSYzDJZJArevQNm2AR  0XPsOSYzDJZJArevQNm2AR
#
#                                                 artists  \
# 383                                                 NaN
# 2300          Catrin Finch, Sinfonia Cymru, John Rutter
# 2301                    BENJIxScarlett, TheeOnlyJanessa
# 2302                                        Diana Krall
# 2303                                       J.J. Johnson
# 2304                                          NAHreally
# 2305  The Bob Florence Limited Edition, Terry Harrin...
# 2306                                      The Sentinals
# 2307                         The Weeknd, Kendrick Lamar
# 2308                                        Naomi Scott
#
#                                              album_name  \
# 383                                                 NaN
# 2300                                           Blessing
# 2301                                  Inside Out 2 Song
# 2302                           When I Look In Your Eyes
# 2303                                             Heroes
# 2304                                         HACKINAWAY
# 2305                                     Serendipity 18
# 2306                                           Big Surf
# 2307  Black Panther The Album Music From And Inspire...
# 2308       Aladdin (Original Motion Picture Soundtrack)
#
#                              track_name  popularity  duration_ms  \
# 383                                 NaN         NaN          NaN
# 2300       Celtic Concerto: 3. Solstice        15.0     173773.0
# 2301                  Inside Out 2 Song        46.0      67558.0
# 2302                 Let's Fall In Love        56.0     258959.0
# 2303     In Walked Wayne - Instrumental         2.0     435560.0
# 2304                         Like Minds        29.0     128000.0
# 2305                              Sugar         8.0     472320.0
# 2306                         Latin Soul        24.0     123706.0
# 2307  Pray For Me (with Kendrick Lamar)        67.0     211440.0
# 2308                  Speechless (Full)        67.0     208800.0
#
#       danceability  energy  tempo
# 383            NaN     NaN    NaN
# 2300           NaN     NaN    NaN
# 2301           NaN     NaN    NaN
# 2302           NaN     NaN    NaN
# 2303           NaN     NaN    NaN
# 2304           NaN     NaN    NaN
# 2305           NaN     NaN    NaN
# 2306           NaN     NaN    NaN
# 2307           NaN     NaN    NaN
# 2308           NaN     NaN    NaN
